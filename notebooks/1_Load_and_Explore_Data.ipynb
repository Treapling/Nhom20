# %%
# Import thư viện xử lý dữ liệu
import pandas as pd

# Đường dẫn đến file dữ liệu gốc (lưu ý đường dẫn tương đối)
file_path = '../data/raw/data_public.csv'

# Đọc file CSV vào một DataFrame (bảng dữ liệu)
df = pd.read_csv(file_path)

# In ra thử 5 dòng đầu tiên để xem máy đã đọc được chưa
display(df.head())

# Xem tổng quan kích thước bảng (có bao nhiêu dòng, bao nhiêu cột)
print("Kích thước dữ liệu gốc:", df.shape)
